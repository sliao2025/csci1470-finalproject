# %%
# import youtube_dl
import yt_dlp
import re
import os
from tqdm import tqdm
import pandas as pd
import numpy as np
# Out:
# /var/folders/5h/xd0mtjm95gj4hw5b9__7w4g80000gn/T/ipykernel_14110/2376082546.py:6: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
WAV_DIR = 'wav_files/'
genre_dict = {
            '/m/064t9': 'Pop_music',
            '/m/0glt670': 'Hip_hop_music',
            '/m/06by7': 'Rock_music',
            '/m/06j6l': 'Rhythm_blues',
            '/m/06cqb': 'Reggae',
            '/m/0y4f8': 'Vocal',
            '/m/07gxw': 'Techno',
            }

genre_set = set(genre_dict.keys())

# %%
temp_str = []
with open('data-files/csv_files/unbalanced_train_segments.csv', 'r') as f:
    temp_str = f.readlines()

# %%
data = np.ones(shape=(1,4)) 
for line in tqdm(temp_str):
    line = re.sub('\s?"', '', line.strip())
    elements = line.split(',')
    common_elements = list(genre_set.intersection(elements[3:]))
    if  common_elements != []:
        data = np.vstack([data, np.array(elements[:3]
                                         + [genre_dict[common_elements[0]]]).reshape(1, 4)])

df = pd.DataFrame(data[1:], columns=['url', 'start_time', 'end_time', 'class_label'])
# Out:
# 100%|██████████| 2041792/2041792 [01:04<00:00, 31694.62it/s]

# %%
print(df.shape)
df.head()
df['class_label'].value_counts()
# Out:
# (52107, 4)
# class_label
# Techno           17017
# Pop_music         8489
# Rock_music        8175
# Hip_hop_music     7618
# Rhythm_blues      4474
# Vocal             3498
# Reggae            2836
# Name: count, dtype: int64

# %%
# Remove 10k Techno audio clips - to make the data more balanced
np.random.seed(10)
drop_indices = np.random.choice(df[df['class_label'] == 'Techno'].index, size=10000, replace=False)
df.drop(labels=drop_indices, axis=0, inplace=True)
df.reset_index(drop=True, inplace=False)

# Time to INT 
df['start_time'] = df['start_time'].map(lambda x: np.int32(float(x)))
df['end_time'] = df['end_time'].map(lambda x: np.int32(float(x)))

# %%
df['class_label'].value_counts()
# Out:
# class_label
# Pop_music        8489
# Rock_music       8175
# Hip_hop_music    7618
# Techno           7017
# Rhythm_blues     4474
# Vocal            3498
# Reggae           2836
# Name: count, dtype: int64

# %% [markdown]
# Example:<br>
# Step 1:<br>
# `ffmpeg -ss 5 -i $(youtube-dl -f 140 --get-url 'https://www.youtube.com/embed/---1_cCGK4M') -t 10 -c:v copy -c:a copy test.mp4`<br>
# Starting time is 5 seconds, duration is 10s.
#
# Refer: https://github.com/rg3/youtube-dl/issues/622
#
# Step 2:<br>
# `ffmpeg -i test.mp4 -vn -acodec pcm_s16le -ar 44100 -ac 1 output.wav` <br>
# PCM-16, 44k sampling, 1-channel (Mono)
# <br>
# Refer: https://superuser.com/questions/609740/extracting-wav-from-mp4-while-preserving-the-highest-possible-quality

# %%
for i, row in tqdm(df.iterrows()):
    url = "'https://www.youtube.com/embed/" + row['url'] + "'"
    file_name = str(i)+"_"+row['class_label']
    
    try:
        command_1 = "ffmpeg -ss " + str(row['start_time']) + " -i $(yt-dlp --verbose -f 140 --get-url " +\
                    url + ") -t 10 -c:v copy -c:a copy " + file_name + ".mp4"

        command_2 = "ffmpeg -i "+ file_name +".mp4 -vn -acodec pcm_s16le -ar 44100 -ac 1 " + WAV_DIR + file_name + ".wav"

        command_3 = 'rm ' + file_name + '.mp4' 

        # Run the 3 commands
        os.system(command_1 + ';' + command_2 + ';' + command_3 + ';')
    
    except:
        print(i, url)
        pass
# Out:
# 0it [00:00, ?it/s][debug] Command-line config: ['--verbose', '-f', '140', '--get-url', 'https://www.youtube.com/embed/--1rvyPa8UM']
# [debug] Encodings: locale UTF-8, fs utf-8, pref UTF-8, out utf-8 (No ANSI), error utf-8 (No ANSI), screen utf-8 (No ANSI)
# [debug] yt-dlp version stable@2024.04.09 from yt-dlp/yt-dlp [ff0779267] (pip)
# [debug] Python 3.10.13 (CPython arm64 64bit) - macOS-14.3-arm64-arm-64bit (OpenSSL 3.2.0 23 Nov 2023)
# [debug] exe versions: ffmpeg 7.0 (setts), ffprobe 7.0
# [debug] Optional libraries: Cryptodome-3.20.0, brotli-1.1.0, certifi-2024.02.02, mutagen-1.47.0, requests-2.31.0, sqlite3-3.44.2, urllib3-2.2.1, websockets-12.0
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, requests, websockets
# [debug] Loaded 1810 extractors
# [youtube] Extracting URL: https://www.youtube.com/embed/--1rvyPa8UM
# [youtube] --1rvyPa8UM: Downloading webpage
# [youtube] --1rvyPa8UM: Downloading ios player API JSON
# [youtube] --1rvyPa8UM: Downloading android player API JSON
# [youtube] --1rvyPa8UM: Downloading m3u8 information
# [debug] Sort order given by extractor: quality, res, fps, hdr:12, source, vcodec:vp9.2, channels, acodec, lang, proto
# [debug] Formats sorted by: hasvid, ie_pref, quality, res, fps, hdr:12(7), source, vcodec:vp9.2(10), channels, acodec, lang, proto, size, br, asr, vext, aext, hasaud, id
# [info] --1rvyPa8UM: Downloading 1 format(s): 140
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr2---sn-ab5sznzs.googlevideo.com/videoplayback?expire=1713914606&ei=ju4nZqjhFLGKkucP15qosAI&ip=2620%3A6e%3A6000%3A3100%3A587e%3Ad284%3A3e58%3A9d4b&id=o-ABjQZH8SW6tD5OM7yxKIlOMn2t2IjN6pfrAn9VAkOTpx&itag=140&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&mh=kI&mm=31%2C26&mn=sn-ab5sznzs%2Csn-p5qlsn76&ms=au%2Conr&mv=m&mvi=2&pl=48&initcwndbps=2798750&vprv=1&svpuc=1&mime=audio%2Fmp4&gir=yes&clen=4947220&dur=305.644&lmt=1700523672950805&mt=1713892653&fvip=4&keepalive=yes&c=IOS&txp=1218224&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cvprv%2Csvpuc%2Cmime%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRQIgFx8_qqMitjjpMyb1j9-LKcDP_bWchebgpOjAvo7QZo4CIQDS-ytR971K8jcmrsb7yQjGmgt3YvkRLF1drbW8c9XEzQ%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=ALClDIEwRQIgEQmxFz9BAdKv-L1EiuaNFJuykIkESptE8wWd-ZWKvL0CIQDXTbgPddgx1OLGSe4_806FVLG9PvvihEzFH2JFqtwx4w%3D%3D':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2023-11-20T23:40:16.000000Z
#   Duration: 00:05:05.64, start: 0.000000, bitrate: 129 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 4 kb/s (default)
#       Metadata:
#         creation_time   : 2023-11-20T23:40:16.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to '0_Hip_hop_music.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 4 kb/s (default)
#       Metadata:
#         creation_time   : 2023-11-20T23:40:16.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x11e639130] video:0KiB audio:157KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.608214%
# size=     159KiB time=00:00:10.06 bitrate= 129.7kbits/s speed=60.2x
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '0_Hip_hop_music.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.02, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'wav_files/0_Hip_hop_music.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf61.1.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x12a1040f0] video:0KiB audio:863KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008830%
# size=     863KiB time=00:00:10.01 bitrate= 705.7kbits/s speed= 825x
# 1it [00:03,  3.03s/it][debug] Command-line config: ['--verbose', '-f', '140', '--get-url', 'https://www.youtube.com/embed/--4kp9W7cNY']
# [debug] Encodings: locale UTF-8, fs utf-8, pref UTF-8, out utf-8 (No ANSI), error utf-8 (No ANSI), screen utf-8 (No ANSI)
# [debug] yt-dlp version stable@2024.04.09 from yt-dlp/yt-dlp [ff0779267] (pip)
# [debug] Python 3.10.13 (CPython arm64 64bit) - macOS-14.3-arm64-arm-64bit (OpenSSL 3.2.0 23 Nov 2023)
# [debug] exe versions: ffmpeg 7.0 (setts), ffprobe 7.0
# [debug] Optional libraries: Cryptodome-3.20.0, brotli-1.1.0, certifi-2024.02.02, mutagen-1.47.0, requests-2.31.0, sqlite3-3.44.2, urllib3-2.2.1, websockets-12.0
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, requests, websockets
# [debug] Loaded 1810 extractors
# [youtube] Extracting URL: https://www.youtube.com/embed/--4kp9W7cNY
# [youtube] --4kp9W7cNY: Downloading webpage
# [youtube] --4kp9W7cNY: Downloading ios player API JSON
# [youtube] --4kp9W7cNY: Downloading android player API JSON
# [youtube] --4kp9W7cNY: Downloading m3u8 information
# [debug] Sort order given by extractor: quality, res, fps, hdr:12, source, vcodec:vp9.2, channels, acodec, lang, proto
# [debug] Formats sorted by: hasvid, ie_pref, quality, res, fps, hdr:12(7), source, vcodec:vp9.2(10), channels, acodec, lang, proto, size, br, asr, vext, aext, hasaud, id
# [info] --4kp9W7cNY: Downloading 1 format(s): 140
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-ab5sznzs.googlevideo.com/videoplayback?expire=1713914608&ei=kO4nZuuVN4GFkucPoqq6mAg&ip=2620%3A6e%3A6000%3A3100%3A587e%3Ad284%3A3e58%3A9d4b&id=o-AAVjoOiq5KSSu1JZzCILn6VhdVKxCyIaFOlX30E1P5kA&itag=140&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&mh=tt&mm=31%2C29&mn=sn-ab5sznzs%2Csn-ab5l6nrs&ms=au%2Crdu&mv=m&mvi=1&pl=48&initcwndbps=2798750&vprv=1&svpuc=1&mime=audio%2Fmp4&gir=yes&clen=5846909&dur=361.232&lmt=1709782751701517&mt=1713892653&fvip=2&keepalive=yes&c=IOS&txp=1218224&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cvprv%2Csvpuc%2Cmime%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRQIgfaVJ0mZDX2Q8qgXHbMHWo1Qk2OaGU--SYlFYIhLkTsYCIQDj_MUcKH3tSG8k8rUvLYfh1cfW5NXKOEYLqtr9HRcF6g%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=ALClDIEwRQIhAP_JUBMEuIhtp6Dys5hB1UGVdjBtA_6yD0Gy2wx1_C7rAiBRusxGtYg4lzqEfo9_UZWmhln5jwulEN3bogJ3qM53_w%3D%3D':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2024-03-07T03:38:35.000000Z
#   Duration: 00:06:01.23, start: 0.000000, bitrate: 129 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 3 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-07T03:38:35.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to '1_Reggae.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 3 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-07T03:38:35.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x13c71f420] video:0KiB audio:157KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.610771%
# size=     159KiB time=00:00:10.06 bitrate= 129.5kbits/s speed=81.1x
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '1_Reggae.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.02, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'wav_files/1_Reggae.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf61.1.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x158e3fc40] video:0KiB audio:863KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008829%
# size=     863KiB time=00:00:10.01 bitrate= 705.7kbits/s speed=1.15e+03x
# 2it [00:05,  2.49s/it][debug] Command-line config: ['--verbose', '-f', '140', '--get-url', 'https://www.youtube.com/embed/--6HJzEIsFs']
# [debug] Encodings: locale UTF-8, fs utf-8, pref UTF-8, out utf-8 (No ANSI), error utf-8 (No ANSI), screen utf-8 (No ANSI)
# [debug] yt-dlp version stable@2024.04.09 from yt-dlp/yt-dlp [ff0779267] (pip)
# [debug] Python 3.10.13 (CPython arm64 64bit) - macOS-14.3-arm64-arm-64bit (OpenSSL 3.2.0 23 Nov 2023)
# [debug] exe versions: ffmpeg 7.0 (setts), ffprobe 7.0
# [debug] Optional libraries: Cryptodome-3.20.0, brotli-1.1.0, certifi-2024.02.02, mutagen-1.47.0, requests-2.31.0, sqlite3-3.44.2, urllib3-2.2.1, websockets-12.0
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, requests, websockets
# [debug] Loaded 1810 extractors
# [youtube] Extracting URL: https://www.youtube.com/embed/--6HJzEIsFs
# [youtube] --6HJzEIsFs: Downloading webpage
# [youtube] --6HJzEIsFs: Downloading ios player API JSON
# [youtube] --6HJzEIsFs: Downloading android player API JSON
# WARNING: [youtube] Skipping player responses from android clients (got player responses for video "aQvGIIdgFDM" instead of "--6HJzEIsFs")
# [youtube] --6HJzEIsFs: Downloading player d8a5aa5e
# [debug] Saving youtube-nsig.d8a5aa5e to cache
# [debug] [youtube] Decrypted nsig 4XOtcLHswLQaACi => Wa6lRxh8cwZD7A
# [debug] Loading youtube-nsig.d8a5aa5e from cache
# [debug] [youtube] Decrypted nsig hhOG5tWQXMnWIno => _XWp7hO620IJZw
# [youtube] --6HJzEIsFs: Downloading m3u8 information
# [debug] Sort order given by extractor: quality, res, fps, hdr:12, source, vcodec:vp9.2, channels, acodec, lang, proto
# [debug] Formats sorted by: hasvid, ie_pref, quality, res, fps, hdr:12(7), source, vcodec:vp9.2(10), channels, acodec, lang, proto, size, br, asr, vext, aext, hasaud, id
# [info] --6HJzEIsFs: Downloading 1 format(s): 140
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-ab5sznz6.googlevideo.com/videoplayback?expire=1713914610&ei=ku4nZqC_N56kkucPgpG8mAE&ip=2620%3A6e%3A6000%3A3100%3A587e%3Ad284%3A3e58%3A9d4b&id=o-AH2oUBW-atvPQrnGKolQyhymcoqD6PRFJtzusYq81iP0&itag=140&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&mh=0v&mm=31%2C29&mn=sn-ab5sznz6%2Csn-ab5l6nk6&ms=au%2Crdu&mv=m&mvi=1&pl=48&initcwndbps=2798750&vprv=1&svpuc=1&mime=audio%2Fmp4&gir=yes&clen=3025798&dur=186.920&lmt=1708568293821931&mt=1713892653&fvip=1&keepalive=yes&c=IOS&txp=1432434&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cvprv%2Csvpuc%2Cmime%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRQIgIf7c5W9zu6L-VWaIttQXIV7qxlDlvnuMD39ktbKHQ8UCIQDn5lll3PjjjmmW8-TCdL13wxlsTXSxVGIpIYMxP52cGw%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=ALClDIEwRAIgQlIjXv240F8wKSxdlU_j7EsfwpelP9fiMDdj8LHxCgECIFFPdTqPhAPVal34gWg5ceXvd2iSYoTupminPovH0NEk':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2024-02-22T02:18:06.000000Z
#   Duration: 00:03:06.92, start: 0.000000, bitrate: 129 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 6 kb/s (default)
#       Metadata:
#         creation_time   : 2024-02-22T02:18:06.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to '2_Rhythm_blues.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 6 kb/s (default)
#       Metadata:
#         creation_time   : 2024-02-22T02:18:06.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x1480436a0] video:0KiB audio:157KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.611515%
# size=     159KiB time=00:00:10.14 bitrate= 128.4kbits/s speed= 101x
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '2_Rhythm_blues.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'wav_files/2_Rhythm_blues.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf61.1.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x15b615230] video:0KiB audio:862KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008836%
# size=     862KiB time=00:00:10.00 bitrate= 705.7kbits/s speed=1.18e+03x
# 3it [00:08,  2.85s/it][debug] Command-line config: ['--verbose', '-f', '140', '--get-url', 'https://www.youtube.com/embed/--AQ3p3ymeE']
# [debug] Encodings: locale UTF-8, fs utf-8, pref UTF-8, out utf-8 (No ANSI), error utf-8 (No ANSI), screen utf-8 (No ANSI)
# [debug] yt-dlp version stable@2024.04.09 from yt-dlp/yt-dlp [ff0779267] (pip)
# [debug] Python 3.10.13 (CPython arm64 64bit) - macOS-14.3-arm64-arm-64bit (OpenSSL 3.2.0 23 Nov 2023)
# [debug] exe versions: ffmpeg 7.0 (setts), ffprobe 7.0
# [debug] Optional libraries: Cryptodome-3.20.0, brotli-1.1.0, certifi-2024.02.02, mutagen-1.47.0, requests-2.31.0, sqlite3-3.44.2, urllib3-2.2.1, websockets-12.0
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, requests, websockets
# [debug] Loaded 1810 extractors
# [youtube] Extracting URL: https://www.youtube.com/embed/--AQ3p3ymeE
# [youtube] --AQ3p3ymeE: Downloading webpage
# [youtube] --AQ3p3ymeE: Downloading ios player API JSON
# [youtube] --AQ3p3ymeE: Downloading android player API JSON
# [youtube] --AQ3p3ymeE: Downloading m3u8 information
# [debug] Sort order given by extractor: quality, res, fps, hdr:12, source, vcodec:vp9.2, channels, acodec, lang, proto
# [debug] Formats sorted by: hasvid, ie_pref, quality, res, fps, hdr:12(7), source, vcodec:vp9.2(10), channels, acodec, lang, proto, size, br, asr, vext, aext, hasaud, id
# [info] --AQ3p3ymeE: Downloading 1 format(s): 140
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr2---sn-ab5l6nrs.googlevideo.com/videoplayback?expire=1713914614&ei=lu4nZujuB52ckucPtJScgAw&ip=2620%3A6e%3A6000%3A3100%3A587e%3Ad284%3A3e58%3A9d4b&id=o-AMxBICw2ueKsrLUok_9-_5WxeA2MmQKzIst-McAxaape&itag=140&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&mh=q0&mm=31%2C26&mn=sn-ab5l6nrs%2Csn-p5qlsndz&ms=au%2Conr&mv=m&mvi=2&pl=48&initcwndbps=2798750&vprv=1&svpuc=1&mime=audio%2Fmp4&gir=yes&clen=2838298&dur=175.333&lmt=1709318917365158&mt=1713892653&fvip=3&keepalive=yes&c=IOS&txp=1318224&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cvprv%2Csvpuc%2Cmime%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRQIhAKUvl7BTgLBPrZZr8dkBe4czVx0CU4Xy9H5vh0MFTYN2AiAs0kfdl-FzOMeEqofgNu6HiNTZ9FLX-P3oGh-l5zUWqQ%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=ALClDIEwRAIgORiDSf4l0uzHUQbU0urV7ylIbB2ZApcjBi7uTMRR8K0CIAhkaj_bUceTki59V-iApbWSgwEQ8RFaKu6aN3HI6XFQ':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2024-03-01T18:48:22.000000Z
#   Duration: 00:02:55.33, start: 0.000000, bitrate: 129 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 7 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-01T18:48:22.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to '3_Rock_music.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 7 kb/s (default)
#       Metadata:
#         creation_time   : 2024-03-01T18:48:22.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x15ae403c0] video:0KiB audio:157KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.611374%
# size=     159KiB time=00:00:10.10 bitrate= 128.9kbits/s speed= 109x
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '3_Rock_music.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.02, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'wav_files/3_Rock_music.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf61.1.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x13f63fe00] video:0KiB audio:863KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008829%
# size=     863KiB time=00:00:10.01 bitrate= 705.7kbits/s speed=1.29e+03x
# 4it [00:10,  2.55s/it][debug] Command-line config: ['--verbose', '-f', '140', '--get-url', 'https://www.youtube.com/embed/--BMVWju1-w']
# [debug] Encodings: locale UTF-8, fs utf-8, pref UTF-8, out utf-8 (No ANSI), error utf-8 (No ANSI), screen utf-8 (No ANSI)
# [debug] yt-dlp version stable@2024.04.09 from yt-dlp/yt-dlp [ff0779267] (pip)
# [debug] Python 3.10.13 (CPython arm64 64bit) - macOS-14.3-arm64-arm-64bit (OpenSSL 3.2.0 23 Nov 2023)
# [debug] exe versions: ffmpeg 7.0 (setts), ffprobe 7.0
# [debug] Optional libraries: Cryptodome-3.20.0, brotli-1.1.0, certifi-2024.02.02, mutagen-1.47.0, requests-2.31.0, sqlite3-3.44.2, urllib3-2.2.1, websockets-12.0
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, requests, websockets
# [debug] Loaded 1810 extractors
# [youtube] Extracting URL: https://www.youtube.com/embed/--BMVWju1-w
# [youtube] --BMVWju1-w: Downloading webpage
# [youtube] --BMVWju1-w: Downloading ios player API JSON
# [youtube] --BMVWju1-w: Downloading android player API JSON
# [youtube] --BMVWju1-w: Downloading m3u8 information
# [debug] Sort order given by extractor: quality, res, fps, hdr:12, source, vcodec:vp9.2, channels, acodec, lang, proto
# [debug] Formats sorted by: hasvid, ie_pref, quality, res, fps, hdr:12(7), source, vcodec:vp9.2(10), channels, acodec, lang, proto, size, br, asr, vext, aext, hasaud, id
# [info] --BMVWju1-w: Downloading 1 format(s): 140
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr3---sn-ab5l6nk6.googlevideo.com/videoplayback?expire=1713914616&ei=mO4nZt3MELGykucPjs6N2As&ip=2620%3A6e%3A6000%3A3100%3A587e%3Ad284%3A3e58%3A9d4b&id=o-AJlDtTTzXs7fqAGz2Ro71GHSd4D-_AKZUOsOrYKKm9xL&itag=140&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&mh=b3&mm=31%2C26&mn=sn-ab5l6nk6%2Csn-p5qlsndz&ms=au%2Conr&mv=m&mvi=3&pl=48&initcwndbps=2798750&vprv=1&svpuc=1&mime=audio%2Fmp4&gir=yes&clen=2629393&dur=162.423&lmt=1700371695037411&mt=1713892653&fvip=4&keepalive=yes&c=IOS&txp=1318224&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cvprv%2Csvpuc%2Cmime%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRQIhAMWSGYEC7Hn25rsfVD9ONX8dIuOlpJK593SyhN_CU-fVAiAQwI7MOQLYXn9GZtTmUXOR_vQ2gif2gHslabsxxQIpag%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=ALClDIEwRgIhALCIuDkvvl97I-vUjBj3b90chQJNNLfvdmKQwjJgzsbUAiEAvGU07-5prsgTH8zEsq-H1fqA7K-dt32TNCuUqVPOcfM%3D':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2023-11-19T05:27:26.000000Z
#   Duration: 00:02:42.42, start: 0.000000, bitrate: 129 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 7 kb/s (default)
#       Metadata:
#         creation_time   : 2023-11-19T05:27:26.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to '4_Rhythm_blues.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 7 kb/s (default)
#       Metadata:
#         creation_time   : 2023-11-19T05:27:26.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x11e7ccb60] video:0KiB audio:157KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.606893%
# size=     160KiB time=00:00:10.12 bitrate= 129.1kbits/s speed= 101x
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '4_Rhythm_blues.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'wav_files/4_Rhythm_blues.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf61.1.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x14c2040e0] video:0KiB audio:862KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008836%
# size=     862KiB time=00:00:10.00 bitrate= 705.7kbits/s speed=1.32e+03x
# 5it [00:12,  2.47s/it][debug] Command-line config: ['--verbose', '-f', '140', '--get-url', 'https://www.youtube.com/embed/--Cc0ZmStCs']
# [debug] Encodings: locale UTF-8, fs utf-8, pref UTF-8, out utf-8 (No ANSI), error utf-8 (No ANSI), screen utf-8 (No ANSI)
# [debug] yt-dlp version stable@2024.04.09 from yt-dlp/yt-dlp [ff0779267] (pip)
# [debug] Python 3.10.13 (CPython arm64 64bit) - macOS-14.3-arm64-arm-64bit (OpenSSL 3.2.0 23 Nov 2023)
# [debug] exe versions: ffmpeg 7.0 (setts), ffprobe 7.0
# [debug] Optional libraries: Cryptodome-3.20.0, brotli-1.1.0, certifi-2024.02.02, mutagen-1.47.0, requests-2.31.0, sqlite3-3.44.2, urllib3-2.2.1, websockets-12.0
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, requests, websockets
# [debug] Loaded 1810 extractors
# [youtube] Extracting URL: https://www.youtube.com/embed/--Cc0ZmStCs
# [youtube] --Cc0ZmStCs: Downloading webpage
# [youtube] --Cc0ZmStCs: Downloading ios player API JSON
# [youtube] --Cc0ZmStCs: Downloading android player API JSON
# WARNING: [youtube] Skipping player responses from android clients (got player responses for video "aQvGIIdgFDM" instead of "--Cc0ZmStCs")
# [debug] Loading youtube-nsig.d8a5aa5e from cache
# [debug] [youtube] Decrypted nsig jXX_aFXw97jpBqs => siNyL8Dld3LNbQ
# [youtube] --Cc0ZmStCs: Downloading m3u8 information
# [debug] Sort order given by extractor: quality, res, fps, hdr:12, source, vcodec:vp9.2, channels, acodec, lang, proto
# [debug] Formats sorted by: hasvid, ie_pref, quality, res, fps, hdr:12(7), source, vcodec:vp9.2(10), channels, acodec, lang, proto, size, br, asr, vext, aext, hasaud, id
# [info] --Cc0ZmStCs: Downloading 1 format(s): 140
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr3---sn-ab5l6nrd.googlevideo.com/videoplayback?expire=1713914618&ei=mu4nZpubKrGXkucPwueliAY&ip=2620%3A6e%3A6000%3A3100%3A587e%3Ad284%3A3e58%3A9d4b&id=o-AGSCi3ors4QwIuwoMIUcFglDAafxp4okWweDd5mSKrXW&itag=140&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&mh=6r&mm=31%2C26&mn=sn-ab5l6nrd%2Csn-p5qlsndr&ms=au%2Conr&mv=m&mvi=3&pl=48&initcwndbps=2798750&vprv=1&svpuc=1&mime=audio%2Fmp4&gir=yes&clen=3757138&dur=232.106&lmt=1708564100007653&mt=1713892653&fvip=4&keepalive=yes&c=IOS&txp=1218224&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cvprv%2Csvpuc%2Cmime%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRgIhAJdMckX8xxFkJ3o6zNNLTZqMQDkjFQ2rLX2uRewerfv7AiEA-PcNVDcYbYtdDABBeDd2Nuu-vqfOhI4GCfi6hqlR-Uo%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=ALClDIEwRAIgAiX6mVKdRp_O-lkFPRmdnnFRERmoLMTQe5cDfPzf3NsCIExIEu5z8AIZYVCTgCM5uStTt6trbV7uoFjUg_iLLXxU':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2024-02-22T01:06:34.000000Z
#   Duration: 00:03:52.11, start: 0.000000, bitrate: 129 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 5 kb/s (default)
#       Metadata:
#         creation_time   : 2024-02-22T01:06:34.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to '5_Rhythm_blues.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 5 kb/s (default)
#       Metadata:
#         creation_time   : 2024-02-22T01:06:34.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x14ae05260] video:0KiB audio:157KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.607913%
# size=     159KiB time=00:00:10.07 bitrate= 129.6kbits/s speed= 112x
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '5_Rhythm_blues.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'wav_files/5_Rhythm_blues.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf61.1.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x129f1af70] video:0KiB audio:862KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008836%
# size=     862KiB time=00:00:10.00 bitrate= 705.7kbits/s speed=1.18e+03x
# 6it [00:15,  2.63s/it][debug] Command-line config: ['--verbose', '-f', '140', '--get-url', 'https://www.youtube.com/embed/--Fti-jdXEI']
# [debug] Encodings: locale UTF-8, fs utf-8, pref UTF-8, out utf-8 (No ANSI), error utf-8 (No ANSI), screen utf-8 (No ANSI)
# [debug] yt-dlp version stable@2024.04.09 from yt-dlp/yt-dlp [ff0779267] (pip)
# [debug] Python 3.10.13 (CPython arm64 64bit) - macOS-14.3-arm64-arm-64bit (OpenSSL 3.2.0 23 Nov 2023)
# [debug] exe versions: ffmpeg 7.0 (setts), ffprobe 7.0
# [debug] Optional libraries: Cryptodome-3.20.0, brotli-1.1.0, certifi-2024.02.02, mutagen-1.47.0, requests-2.31.0, sqlite3-3.44.2, urllib3-2.2.1, websockets-12.0
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, requests, websockets
# [debug] Loaded 1810 extractors
# [youtube] Extracting URL: https://www.youtube.com/embed/--Fti-jdXEI
# [youtube] --Fti-jdXEI: Downloading webpage
# ...
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr2---sn-ab5sznzr.googlevideo.com/videoplayback?expire=1713914633&ei=qe4nZvj0AeuLkucPrKq9oAI&ip=2620%3A6e%3A6000%3A3100%3A587e%3Ad284%3A3e58%3A9d4b&id=o-AAwMMcVZCFuZ_PH3BubAYwQmJM35DhjQtzb-RmD-XfKX&itag=140&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&mh=iW&mm=31%2C29&mn=sn-ab5sznzr%2Csn-ab5l6nrr&ms=au%2Crdu&mv=m&mvi=2&pl=48&initcwndbps=2798750&vprv=1&svpuc=1&mime=audio%2Fmp4&gir=yes&clen=7657437&dur=473.106&lmt=1709134859531350&mt=1713892653&fvip=2&keepalive=yes&c=IOS&txp=1432434&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cvprv%2Csvpuc%2Cmime%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRQIhAMS7h7FIiaH3cBWcnZ9-iyA1GVUK7z8T-NIyE54p6KtXAiAuiTrN2opBV8-W57KBIJlAZLUI8W7tfojrM9KW8-6pDQ%3D%3D&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=ALClDIEwRQIhAIVBuKp8dZ0LMXwLBzz9LJWyZoZk0jw5xhAJxn6ITy0NAiBzuhAhNpcrW9YZKLD5R5He2ElIltPfWpLQFabPnHGBBQ%3D%3D':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2024-02-28T15:40:11.000000Z
#   Duration: 00:07:53.11, start: 0.000000, bitrate: 129 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 2 kb/s (default)
#       Metadata:
#         creation_time   : 2024-02-28T15:40:11.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to '11_Reggae.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 2 kb/s (default)
#       Metadata:
#         creation_time   : 2024-02-28T15:40:11.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x124afdde0] video:0KiB audio:157KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.605373%
# size=     159KiB time=00:00:10.19 bitrate= 128.1kbits/s speed= 100x
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '11_Reggae.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 128 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'wav_files/11_Reggae.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf61.1.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x155725b20] video:0KiB audio:862KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008837%
# size=     862KiB time=00:00:10.00 bitrate= 705.7kbits/s speed= 890x
# 11it [00:29,  2.57s/it][debug] Command-line config: ['--verbose', '-f', '140', '--get-url', 'https://www.youtube.com/embed/--S2EYGEwfE']
# [debug] Encodings: locale UTF-8, fs utf-8, pref UTF-8, out utf-8 (No ANSI), error utf-8 (No ANSI), screen utf-8 (No ANSI)
# [debug] yt-dlp version stable@2024.04.09 from yt-dlp/yt-dlp [ff0779267] (pip)
# [debug] Python 3.10.13 (CPython arm64 64bit) - macOS-14.3-arm64-arm-64bit (OpenSSL 3.2.0 23 Nov 2023)
# [debug] exe versions: ffmpeg 7.0 (setts), ffprobe 7.0
# [debug] Optional libraries: Cryptodome-3.20.0, brotli-1.1.0, certifi-2024.02.02, mutagen-1.47.0, requests-2.31.0, sqlite3-3.44.2, urllib3-2.2.1, websockets-12.0
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, requests, websockets
# [debug] Loaded 1810 extractors
# [youtube] Extracting URL: https://www.youtube.com/embed/--S2EYGEwfE
# [youtube] --S2EYGEwfE: Downloading webpage
# [youtube] --S2EYGEwfE: Downloading ios player API JSON
# [youtube] --S2EYGEwfE: Downloading android player API JSON
# [youtube] --S2EYGEwfE: Downloading m3u8 information
# [debug] Sort order given by extractor: quality, res, fps, hdr:12, source, vcodec:vp9.2, channels, acodec, lang, proto
# [debug] Formats sorted by: hasvid, ie_pref, quality, res, fps, hdr:12(7), source, vcodec:vp9.2(10), channels, acodec, lang, proto, size, br, asr, vext, aext, hasaud, id
# [info] --S2EYGEwfE: Downloading 1 format(s): 140
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'https://rr1---sn-ab5l6nkd.googlevideo.com/videoplayback?expire=1713914635&ei=q-4nZoTCFvOTkucPjoKBsAY&ip=2620%3A6e%3A6000%3A3100%3A587e%3Ad284%3A3e58%3A9d4b&id=o-AJCiajwjbmaNLe-k4hVNf4qVAJpm6MpzI7MTHLJpjFmR&itag=140&source=youtube&requiressl=yes&xpc=EgVo2aDSNQ%3D%3D&mh=OJ&mm=31%2C29&mn=sn-ab5l6nkd%2Csn-ab5sznld&ms=au%2Crdu&mv=m&mvi=1&pl=48&initcwndbps=2798750&vprv=1&svpuc=1&mime=audio%2Fmp4&gir=yes&clen=5585315&dur=345.071&lmt=1704415452377008&mt=1713892653&fvip=3&keepalive=yes&c=IOS&txp=1218224&sparams=expire%2Cei%2Cip%2Cid%2Citag%2Csource%2Crequiressl%2Cxpc%2Cvprv%2Csvpuc%2Cmime%2Cgir%2Cclen%2Cdur%2Clmt&sig=AJfQdSswRAIgPjKmLCyqjuXbkuD3-r-BxK-ThuOaQIxKLQsAAUzAyZUCIHJ00gQGKVe8J4M13LY6iveLyalqdQfr2bWNX0CKPS-Y&lsparams=mh%2Cmm%2Cmn%2Cms%2Cmv%2Cmvi%2Cpl%2Cinitcwndbps&lsig=ALClDIEwRAIgDzCI25pDb1y1h29px-AikxiRRPc-1Iu8vcTQv71j4A8CIArSmMjJQ7RszMElA-dwja30fVqurbKbPpHV0bO8-5FV':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     creation_time   : 2024-01-05T00:44:03.000000Z
#   Duration: 00:05:45.07, start: 0.000000, bitrate: 129 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 3 kb/s (default)
#       Metadata:
#         creation_time   : 2024-01-05T00:44:03.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp4, to '12_Techno.mp4':
#   Metadata:
#     major_brand     : dash
#     minor_version   : 0
#     compatible_brands: iso6mp41
#     encoder         : Lavf61.1.100
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 3 kb/s (default)
#       Metadata:
#         creation_time   : 2024-01-05T00:44:03.000000Z
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Press [q] to stop, [?] for help
# [out#0/mp4 @ 0x142929870] video:0KiB audio:157KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.610691%
# size=     159KiB time=00:00:10.10 bitrate= 129.1kbits/s speed=78.2x
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '12_Techno.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf61.1.100
#   Duration: 00:00:10.01, start: 0.000000, bitrate: 130 kb/s
#   Stream #0:0[0x1](und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'wav_files/12_Techno.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf61.1.100
#   Stream #0:0(und): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 44100 Hz, mono, s16, 705 kb/s (default)
#       Metadata:
#         handler_name    : ISO Media file produced by Google Inc.
#         vendor_id       : [0][0][0][0]
#         encoder         : Lavc61.3.100 pcm_s16le
# [out#0/wav @ 0x1509099b0] video:0KiB audio:862KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.008836%
# size=     862KiB time=00:00:10.00 bitrate= 705.7kbits/s speed=1.18e+03x
# 12it [00:32,  2.62s/it][debug] Command-line config: ['--verbose', '-f', '140', '--get-url', 'https://www.youtube.com/embed/--WxoinaQzk']
# [debug] Encodings: locale UTF-8, fs utf-8, pref UTF-8, out utf-8 (No ANSI), error utf-8 (No ANSI), screen utf-8 (No ANSI)
# [debug] yt-dlp version stable@2024.04.09 from yt-dlp/yt-dlp [ff0779267] (pip)
# [debug] Python 3.10.13 (CPython arm64 64bit) - macOS-14.3-arm64-arm-64bit (OpenSSL 3.2.0 23 Nov 2023)
# [debug] exe versions: ffmpeg 7.0 (setts), ffprobe 7.0
# [debug] Optional libraries: Cryptodome-3.20.0, brotli-1.1.0, certifi-2024.02.02, mutagen-1.47.0, requests-2.31.0, sqlite3-3.44.2, urllib3-2.2.1, websockets-12.0
# [debug] Proxy map: {}
# [debug] Request Handlers: urllib, requests, websockets
# [debug] Loaded 1810 extractors
# [youtube] Extracting URL: https://www.youtube.com/embed/--WxoinaQzk
# [youtube] --WxoinaQzk: Downloading webpage
# [youtube] --WxoinaQzk: Downloading ios player API JSON
# [youtube] --WxoinaQzk: Downloading android player API JSON
# WARNING: [youtube] Skipping player responses from android clients (got player responses for video "aQvGIIdgFDM" instead of "--WxoinaQzk")
# [debug] Loading youtube-nsig.d8a5aa5e from cache
# [debug] [youtube] Decrypted nsig TYcKAdBLpvMDIOL => OINrssy7Hvm4fA
# [debug] Loading youtube-nsig.d8a5aa5e from cache
# [debug] [youtube] Decrypted nsig SnNBn26Lw_Hb2sy => HrWd-q3PJCQTOw
# [youtube] --WxoinaQzk: Downloading m3u8 information
# [debug] Sort order given by extractor: quality, res, fps, hdr:12, source, vcodec:vp9.2, channels, acodec, lang, proto
# [debug] Formats sorted by: hasvid, ie_pref, quality, res, fps, hdr:12(7), source, vcodec:vp9.2(10), channels, acodec, lang, proto, size, br, asr, vext, aext, hasaud, id
# [info] --WxoinaQzk: Downloading 1 format(s): 140
# ffmpeg version 7.0 Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
